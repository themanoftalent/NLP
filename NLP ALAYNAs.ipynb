# %% [markdown]
# <a href="https://colab.research.google.com/github/themanoftalent/NLP/blob/main/NLP%20ALAYNAs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# `Anamoor 1`
# ####REGEX

# %%
import re
from typing import List

# %%
def username(text:str) -> List[str]:
  print(re.findall(r"([^\s@]+)@\S+", text))

# %%
a= "New regsitered users are : akif.can@gmail.com, akif@gmail.com"
username(a)
# Out:
# ['akif.can', 'akif']

# %% [markdown]
# ```
# Anamoor 2
# ```
# ####TOKENLESTIRME

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from collections import Counter

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def cleaning(data):
    stop_words = stopwords.words('english')
    #lem = WordNetLemmatizer()
    #1 . Tokenize
    text_tokens = word_tokenize(data)
    #2. Remove Puncs
    #tokens_without_punc = [w for w in text_tokens if w.isalpha() or w.isdigit()]
    #3. Removing Stopwords
    tokens_without_sw = [t for t in text_tokens if t not in stop_words]
    #4. lemma
   #text_cleaned = [lem.lemmatize(t) for t in tokens_without_sw]
    #join
    return ' '.join(tokens_without_sw)

# %%
text = """ It says the world's wealthiest 1% produce double the combined carbon emission of the poor est 50%, according to the UN.  The wealthiest 5% alone - the so-called "poll uter elite" - contributed 37% of emission growth between 1990 and 2015.
"""
cleaning(text)
# Out:
# "It says world 's wealthiest 1 % produce double combined carbon emission poor est 50 % , according UN . The wealthiest 5 % alone - so-called `` poll uter elite '' - contributed 37 % emission growth 1990 2015 ."

# %% [markdown]
# `Anamoor 3`
# ####ÇALIŞMAYAN COMPOSE

# %%
def compose(x):
  return x+1
    if len(list) == 1:
        return lambda x:list[0](x)
    list.reverse()
    final=lambda x:x
    for f in list:
        final=lambda x:f(final(x))
    return final
# Out:
#   File "<ipython-input-6-a7bc91368482>", line 3
#     if len(list) == 1:
#     ^
# IndentationError: unexpected indent

# %%
f1 = f1_score(testy, yhat_classes)
print('F1 score: %f' % f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0bd9dc78ce6f> in <module>()
# ----> 1 f1 = f1_score(testy, yhat_classes)
#       2 print('F1 score: %f' % f1)
#
# NameError: name 'f1_score' is not defined

# %% [markdown]
# ```
# Anamoor 4
# ```
# ####PARENTEZ MATCH

# %%
def check(expression):
	
	open_tup = tuple('({[')
	close_tup = tuple(')}]')
	map = dict(zip(open_tup, close_tup))
	queue = []

	for i in expression:
		if i in open_tup:
			queue.append(map[i])
		elif i in close_tup:
			if not queue or i != queue.pop():
				return "False"
	if not queue:
		return "True"
	else:
		return "False"

# %%
check("{[(])}")
# Out:
# 'False'

# %%
check("[()}")
# Out:
# 'False'

# %% [markdown]
# ```
# Anamoor 5
# ```
# ####NEWTON TORCH

# %%
import torch

# %%
# initial guess
guess = torch.tensor([1], dtype=torch.float64, requires_grad = True) 

# function to optimize
def my_func(x): 
    return x - torch.cos(x)

def newton(func, runs=5): 
    for _ in range(runs): 
        # evaluate our function with current value of `guess`
        value = my_func(guess)
        value.backward()
        # update our `guess` based on the gradient
        guess.data -= (value / guess.grad).data
        # zero out current gradient to hold new gradients in next iteration 
        guess.grad.data.zero_() 
    return guess.data # return our final `guess` after 5 updates

# # call starts
# result = newton(my_func, guess)

# # output of `result`
# tensor([0.7391], dtype=torch.float64)

# %%
my_func(torch.tensor(1.))==torch.tensor(2.2)
newton(torch.tensor(2.25))==torch.tensor(6.25)
my_func(torch.tensor(-1.2))==torch.tensor(0)
# Out:
# tensor(False)

# %% [markdown]
# ```
# Anamoor 6
# ```
# ####MOST frequest

# %%
import numpy as np
from typing import Union
from collections import Counter

# %%
def most_frequest(arr:np.array)-> Union[int,float,str]:
  arr.sort()
  maximum = 1; output = arr[0]; current_count = 1

  for i in range(1,n):
    if (arr[i] == arr[i - 1]):
      current_count +=1

    else:
      if (current_count > maximum):
        maximum = current_count
        output = arr[i - 1]
      current_count = 1

  if (current_count > maximum):
    maximum = current_count
    output = arr[n- 1]
  return output

# %%
arr=np.array(["a","e","b","a","c","a","e","d","e","e","e"])
n=len(arr)
most_frequest(arr)
# Out:
# 'e'

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %%
# The question I am tackling with is about single-linked list
# I have x1 -> x2 -> …None
# Where x are element of this list and are called nodes. Each node stores some data.
# I have tried 
class Node:
  def __init__(self,value:int):
    self.value = value
    self.next = None 

# here I write a second method like merge
  
  def merge(list1:Node, list2:Node) -> Node:
      head = list1
      while head.next:
          head = head.next
      head.next = list2
      return list1



# I will join two lists, but the state of the arguments should not change
listem=([1,2,3])
listem2=([4,5,6])
n1=Node(1)
n2=Node(2)
# Out:
# <__main__.Node object at 0x7fd8b4d2cb50>
